# %%
# Pipeline parameters — overridden by job base_parameters when run via DAB.
dbutils.widgets.text("catalog", "actuarial")
dbutils.widgets.text("schema", "streaming")
dbutils.widgets.text("volume_name", "landing")

catalog = dbutils.widgets.get("catalog")
schema = dbutils.widgets.get("schema")
volume_name = dbutils.widgets.get("volume_name")

volume_path = f"/Volumes/{catalog}/{schema}/{volume_name}"
print(f"catalog={catalog}  schema={schema}  volume_path={volume_path}")

# %% [markdown]
# # Setup — Create Schema and Landing Volume
#
# ## Step 1 - Create Schema

# %%
spark.sql(f"""
CREATE SCHEMA IF NOT EXISTS {catalog}.{schema}
COMMENT 'Schema for actuarial streaming bronze (Auto Loader Streaming Tables)'
""")

# %% [markdown]
# ## Step 2 - Create Landing Volume

# %%
spark.sql(f"""
CREATE VOLUME IF NOT EXISTS {catalog}.{schema}.{volume_name}
COMMENT 'Volume for landing CSV batches for streaming bronze Auto Loader'
""")
print(f"Ready: {volume_path}")
