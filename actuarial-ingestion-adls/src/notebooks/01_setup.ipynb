# %%
# Pipeline parameters — overridden by job base_parameters when run via DAB.
dbutils.widgets.text("catalog", "actuarial")
dbutils.widgets.text("schema", "ingestion")

catalog = dbutils.widgets.get("catalog")
schema = dbutils.widgets.get("schema")
print(f"catalog={catalog}  schema={schema}")

# %% [markdown]
# # Setup — Create Schema
#
# Creates the Unity Catalog schema for batch Auto Loader bronze tables. Landing and Autoloader state live on ADLS (`abfss://`) under the actuarial external location.

# %%
spark.sql(f"""
CREATE SCHEMA IF NOT EXISTS {catalog}.{schema}
COMMENT 'Schema for actuarial batch Auto Loader bronze ingest from ADLS'
""")
print(f"Ready: {catalog}.{schema}")
