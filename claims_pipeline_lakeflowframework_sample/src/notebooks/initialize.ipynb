# %% [markdown]
# # Initialize Variables
#
# Shared catalog / schema / volume paths for setup and landing notebooks.

# %%
dbutils.widgets.text("catalog", "actuarial")

catalog = dbutils.widgets.get("catalog")
# All medallion layers share actuarial.sample; table names stay layer-distinct.
sample_schema = f"{catalog}.sample"
bronze_schema = sample_schema
silver_schema = sample_schema
gold_schema = sample_schema
landing_volume = "landing"
volume_root_file_path = f"/Volumes/{catalog}/sample/{landing_volume}"

print(f"catalog={catalog}")
print(f"sample_schema={sample_schema}")
print(f"bronze_schema={bronze_schema}")
print(f"silver_schema={silver_schema}")
print(f"gold_schema={gold_schema}")
print(f"volume_root_file_path={volume_root_file_path}")
