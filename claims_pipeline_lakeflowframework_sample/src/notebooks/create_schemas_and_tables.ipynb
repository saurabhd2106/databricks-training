# %% [markdown]
# # Create Catalog, Schema, and Landing Volume
#
# Idempotent bootstrap for `actuarial.sample`. Prefer creating the catalog/schema before the first `bundle deploy` so the volume resource can attach.

# %%
# %run "./initialize"

# %%
# Catalog `actuarial` is provisioned outside this job (metastore managed location).
# Only ensure schema + volume so the job can land files.
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {sample_schema}")
spark.sql(f"CREATE VOLUME IF NOT EXISTS {sample_schema}.{landing_volume}")
print(f"Schema and landing volume ready: {sample_schema}.{landing_volume}")
